# %%
import pandas as pd
from textblob import TextBlob

# Sample Reviews
data = {
    "Review": [
        "This product is amazing",
        "I love this service",
        "The experience was fantastic",
        "Very bad quality",
        "I am disappointed",
        "Worst purchase ever"
    ]
}

df = pd.DataFrame(data)

# Sentiment Function
def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# Apply Sentiment Analysis
df["Sentiment"] = df["Review"].apply(get_sentiment)

# Display Results
print("Sentiment Analysis Results")
print(df)

# Count Sentiments
print("\nSentiment Summary")
print(df["Sentiment"].value_counts())
# Out:
# Sentiment Analysis Results
#                          Review Sentiment
# 0       This product is amazing  Positive
# 1           I love this service  Positive
# 2  The experience was fantastic  Positive
# 3              Very bad quality  Negative
# 4             I am disappointed  Negative
# 5           Worst purchase ever  Negative
#
# Sentiment Summary
# Sentiment
# Positive    3
# Negative    3
# Name: count, dtype: int64
